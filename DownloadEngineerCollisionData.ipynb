# %% [markdown]
# # Download & Engineer Los Angeles Collisions Data
# ### Tiffany Chan
# <br>
# The purpose of this notebook is to download 2024 collision data from the Los Angeles Open Data portal. This dataset is engineered to add fields and edit existing fields, before being exporting the data to a CSV file.

# %% [markdown]
# ---
# ### Part I: Set Up & Read Dataset

# %%
import pandas as pd
from datetime import date, datetime

# %% [markdown]
# Return the current local date

# %%
today = date.today()
print("Run date: ", today)
# Out:
# Run date:  2025-01-28

# %% [markdown]
# Get download URL

# %%
url = 'https://data.lacity.org/api/views/d5tf-ez2w/rows.csv?accessType=DOWNLOAD'

# %% [markdown]
# Read the data

# %%
df = pd.read_csv(url)
df.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID   Area Name  \
# 0  190319651    08/24/2019    08/24/2019            450        3   Southwest
# 1  190319680    08/30/2019    08/30/2019           2320        3   Southwest
# 2  190413769    08/25/2019    08/25/2019            545        4  Hollenbeck
# 3  190127578    11/20/2019    11/20/2019            350        1     Central
# 4  190319695    08/30/2019    08/30/2019           2100        3   Southwest
#
#    Reporting District  Crime Code Crime Code Description  \
# 0                 356         997      TRAFFIC COLLISION
# 1                 355         997      TRAFFIC COLLISION
# 2                 422         997      TRAFFIC COLLISION
# 3                 128         997      TRAFFIC COLLISION
# 4                 374         997      TRAFFIC COLLISION
#
#                              MO Codes  Victim Age Victim Sex Victim Descent  \
# 0            3036 3004 3026 3101 4003        22.0          M              H
# 1  3037 3006 3028 3030 3039 3101 4003        30.0          F              H
# 2            3101 3401 3701 3006 3030         NaN          M              X
# 3       0605 3101 3401 3701 3011 3034        21.0          M              H
# 4       0605 4025 3037 3004 3025 3101        49.0          M              B
#
#    Premise Code Premise Description                          Address  \
# 0         101.0              STREET  JEFFERSON                    BL
# 1         101.0              STREET  JEFFERSON                    BL
# 2         101.0              STREET                      N  BROADWAY
# 3         101.0              STREET                              1ST
# 4         101.0              STREET            MARTIN LUTHER KING JR
#
#                          Cross Street              Location
# 0     NORMANDIE                    AV  (34.0255, -118.3002)
# 1                          W  WESTERN  (34.0256, -118.3089)
# 2  W  EASTLAKE                     AV  (34.0738, -118.2078)
# 3                             CENTRAL  (34.0492, -118.2391)
# 4     ARLINGTON                    AV  (34.0108, -118.3182)

# %% [markdown]
# ---
# ### Part II: Data Engineering

# %% [markdown]
# #### 1) Create timestamp
# Use "Date Occured field"

# %%
timestamp = df['Date Occurred']
timestamp = pd.to_datetime(timestamp)

# %% [markdown]
# #### 2) Filter to 2024
# Create a new field for the year

# %%
year = []

for t in timestamp:
    yr = t.year
    year.append(yr)

df.insert(0,"Year", year)

# %% [markdown]
# Filter for only collisions in 2024

# %%
df = df[df['Year'] == 2024]
df.head()
# Out:
#        Year  DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 19678  2024  240406645    03/13/2024    03/10/2024           1900        4
# 45031  2024  241307843    03/28/2024    03/27/2024           2340       13
# 45311  2024  241214094    08/05/2024    08/05/2024            835       12
# 47337  2024  240110106    04/09/2024    04/09/2024            950        1
# 68491  2024  240115072    07/21/2024    07/21/2024            235        1
#
#          Area Name  Reporting District  Crime Code Crime Code Description  \
# 19678   Hollenbeck                 412         997      TRAFFIC COLLISION
# 45031       Newton                1321         997      TRAFFIC COLLISION
# 45311  77th Street                1256         997      TRAFFIC COLLISION
# 47337      Central                 119         997      TRAFFIC COLLISION
# 68491      Central                 195         997      TRAFFIC COLLISION
#
#                                                 MO Codes  Victim Age  \
# 19678                                     0605 3030 4024        31.0
# 45031  0605 3011 3028 3033 3034 3036 3101 4013 3401 3701        25.0
# 45311                                                NaN        30.0
# 47337  3401 3701 0605 3004 3026 3029 3033 3037 3101 4024        32.0
# 68491  0605 3004 3025 3029 3035 3036 3101 4024 3401 3701        25.0
#
#       Victim Sex Victim Descent  Premise Code Premise Description  \
# 19678          M              C         101.0              STREET
# 45031          M              O         102.0            SIDEWALK
# 45311          M              H         101.0              STREET
# 47337          M              O         101.0              STREET
# 68491          M              H         101.0              STREET
#
#                                Address                     Cross Street  \
# 19678                 200 W  AVENUE 26                              NaN
# 45031                            ADAMS                            GRAND
# 45311                         FLORENCE                            GRAND
# 47337                           VIGNES                          BAUCHET
# 68491  17TH                         ST  LOS ANGELES                  ST
#
#                    Location
# 19678  (34.0786, -118.2174)
# 45031  (34.0265, -118.2723)
# 45311  (33.9747, -118.2803)
# 47337  (34.0589, -118.2323)
# 68491  (34.0323, -118.2621)

# %% [markdown]
# Remove the year column to remove clutter

# %%
df.drop('Year', axis=1, inplace=True)

# %% [markdown]
# #### 3) Add latitude & longitude
# Separate "Location" field into latitude & longitude

# %%
lat = []
for n in df['Location']:
    split = n.split(', ')
    first_num = split[0]
    latitude = first_num[1:]
    lat.append(latitude)
    
lon = []
for n in df['Location']:
    split = n.split(', ')
    second_num = split[1]
    longitude = second_num[:-1]
    lon.append(longitude)

# %% [markdown]
# Create two new fields for storing the data & delete the "Location" field

# %%
df.insert(18, "Latitude", lat)
df.insert(19, "Longitude", lon)

df.drop('Location', axis=1, inplace=True)
df.head()
# Out:
#        DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 19678  240406645    03/13/2024    03/10/2024           1900        4
# 45031  241307843    03/28/2024    03/27/2024           2340       13
# 45311  241214094    08/05/2024    08/05/2024            835       12
# 47337  240110106    04/09/2024    04/09/2024            950        1
# 68491  240115072    07/21/2024    07/21/2024            235        1
#
#          Area Name  Reporting District  Crime Code Crime Code Description  \
# 19678   Hollenbeck                 412         997      TRAFFIC COLLISION
# 45031       Newton                1321         997      TRAFFIC COLLISION
# 45311  77th Street                1256         997      TRAFFIC COLLISION
# 47337      Central                 119         997      TRAFFIC COLLISION
# 68491      Central                 195         997      TRAFFIC COLLISION
#
#                                                 MO Codes  Victim Age  \
# 19678                                     0605 3030 4024        31.0
# 45031  0605 3011 3028 3033 3034 3036 3101 4013 3401 3701        25.0
# 45311                                                NaN        30.0
# 47337  3401 3701 0605 3004 3026 3029 3033 3037 3101 4024        32.0
# 68491  0605 3004 3025 3029 3035 3036 3101 4024 3401 3701        25.0
#
#       Victim Sex Victim Descent  Premise Code Premise Description  \
# 19678          M              C         101.0              STREET
# 45031          M              O         102.0            SIDEWALK
# 45311          M              H         101.0              STREET
# 47337          M              O         101.0              STREET
# 68491          M              H         101.0              STREET
#
#                                Address                     Cross Street  \
# 19678                 200 W  AVENUE 26                              NaN
# 45031                            ADAMS                            GRAND
# 45311                         FLORENCE                            GRAND
# 47337                           VIGNES                          BAUCHET
# 68491  17TH                         ST  LOS ANGELES                  ST
#
#       Latitude  Longitude
# 19678  34.0786  -118.2174
# 45031  34.0265  -118.2723
# 45311  33.9747  -118.2803
# 47337  34.0589  -118.2323
# 68491  34.0323  -118.2621

# %% [markdown]
# #### 4) Add month of the year
# Derive from "Date Occurred" field

# %%
timestamp = df['Date Occurred']
timestamp = pd.to_datetime(timestamp)

month = []

# get month from timestamp
for t in timestamp:
    m = t.month_name()
    month.append(m)

# add month data to dataframe
df.insert(3, "Month", month)
df.head()
# Out:
#        DR Number Date Reported Date Occurred   Month  Time Occurred  Area ID  \
# 19678  240406645    03/13/2024    03/10/2024   March           1900        4
# 45031  241307843    03/28/2024    03/27/2024   March           2340       13
# 45311  241214094    08/05/2024    08/05/2024  August            835       12
# 47337  240110106    04/09/2024    04/09/2024   April            950        1
# 68491  240115072    07/21/2024    07/21/2024    July            235        1
#
#          Area Name  Reporting District  Crime Code Crime Code Description  \
# 19678   Hollenbeck                 412         997      TRAFFIC COLLISION
# 45031       Newton                1321         997      TRAFFIC COLLISION
# 45311  77th Street                1256         997      TRAFFIC COLLISION
# 47337      Central                 119         997      TRAFFIC COLLISION
# 68491      Central                 195         997      TRAFFIC COLLISION
#
#                                                 MO Codes  Victim Age  \
# 19678                                     0605 3030 4024        31.0
# 45031  0605 3011 3028 3033 3034 3036 3101 4013 3401 3701        25.0
# 45311                                                NaN        30.0
# 47337  3401 3701 0605 3004 3026 3029 3033 3037 3101 4024        32.0
# 68491  0605 3004 3025 3029 3035 3036 3101 4024 3401 3701        25.0
#
#       Victim Sex Victim Descent  Premise Code Premise Description  \
# 19678          M              C         101.0              STREET
# 45031          M              O         102.0            SIDEWALK
# 45311          M              H         101.0              STREET
# 47337          M              O         101.0              STREET
# 68491          M              H         101.0              STREET
#
#                                Address                     Cross Street  \
# 19678                 200 W  AVENUE 26                              NaN
# 45031                            ADAMS                            GRAND
# 45311                         FLORENCE                            GRAND
# 47337                           VIGNES                          BAUCHET
# 68491  17TH                         ST  LOS ANGELES                  ST
#
#       Latitude  Longitude
# 19678  34.0786  -118.2174
# 45031  34.0265  -118.2723
# 45311  33.9747  -118.2803
# 47337  34.0589  -118.2323
# 68491  34.0323  -118.2621

# %% [markdown]
# #### 5) Add hour of the day
# Derive from "Time Occurred" field

# %%
hour = (df['Time Occurred']/100).astype(int)
df.insert(4, "Hour", hour)
df.head()
# Out:
#        DR Number Date Reported Date Occurred   Month  Hour  Time Occurred  \
# 19678  240406645    03/13/2024    03/10/2024   March    19           1900
# 45031  241307843    03/28/2024    03/27/2024   March    23           2340
# 45311  241214094    08/05/2024    08/05/2024  August     8            835
# 47337  240110106    04/09/2024    04/09/2024   April     9            950
# 68491  240115072    07/21/2024    07/21/2024    July     2            235
#
#        Area ID    Area Name  Reporting District  Crime Code  ...  \
# 19678        4   Hollenbeck                 412         997  ...
# 45031       13       Newton                1321         997  ...
# 45311       12  77th Street                1256         997  ...
# 47337        1      Central                 119         997  ...
# 68491        1      Central                 195         997  ...
#
#                                                 MO Codes Victim Age  \
# 19678                                     0605 3030 4024       31.0
# 45031  0605 3011 3028 3033 3034 3036 3101 4013 3401 3701       25.0
# 45311                                                NaN       30.0
# 47337  3401 3701 0605 3004 3026 3029 3033 3037 3101 4024       32.0
# 68491  0605 3004 3025 3029 3035 3036 3101 4024 3401 3701       25.0
#
#        Victim Sex Victim Descent Premise Code  Premise Description  \
# 19678           M              C        101.0               STREET
# 45031           M              O        102.0             SIDEWALK
# 45311           M              H        101.0               STREET
# 47337           M              O        101.0               STREET
# 68491           M              H        101.0               STREET
#
#                                Address                     Cross Street  \
# 19678                 200 W  AVENUE 26                              NaN
# 45031                            ADAMS                            GRAND
# 45311                         FLORENCE                            GRAND
# 47337                           VIGNES                          BAUCHET
# 68491  17TH                         ST  LOS ANGELES                  ST
#
#       Latitude  Longitude
# 19678  34.0786  -118.2174
# 45031  34.0265  -118.2723
# 45311  33.9747  -118.2803
# 47337  34.0589  -118.2323
# 68491  34.0323  -118.2621
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 6) Add day of week
# Derive from "Date Occurred" field

# %%
timestamp = df['Date Occurred']
timestamp = pd.to_datetime(timestamp)

day_of_week = []

# get day of week from timestamp
for t in timestamp:
    day = t.day_name()
    day_of_week.append(day)

# add day of week data to dataframe
df.insert(3, "Day Of Week", day_of_week)
df.head()
# Out:
#        DR Number Date Reported Date Occurred Day Of Week   Month  Hour  \
# 19678  240406645    03/13/2024    03/10/2024      Sunday   March    19
# 45031  241307843    03/28/2024    03/27/2024   Wednesday   March    23
# 45311  241214094    08/05/2024    08/05/2024      Monday  August     8
# 47337  240110106    04/09/2024    04/09/2024     Tuesday   April     9
# 68491  240115072    07/21/2024    07/21/2024      Sunday    July     2
#
#        Time Occurred  Area ID    Area Name  Reporting District  ...  \
# 19678           1900        4   Hollenbeck                 412  ...
# 45031           2340       13       Newton                1321  ...
# 45311            835       12  77th Street                1256  ...
# 47337            950        1      Central                 119  ...
# 68491            235        1      Central                 195  ...
#
#                                                 MO Codes Victim Age  \
# 19678                                     0605 3030 4024       31.0
# 45031  0605 3011 3028 3033 3034 3036 3101 4013 3401 3701       25.0
# 45311                                                NaN       30.0
# 47337  3401 3701 0605 3004 3026 3029 3033 3037 3101 4024       32.0
# 68491  0605 3004 3025 3029 3035 3036 3101 4024 3401 3701       25.0
#
#       Victim Sex  Victim Descent Premise Code Premise Description  \
# 19678          M               C        101.0              STREET
# 45031          M               O        102.0            SIDEWALK
# 45311          M               H        101.0              STREET
# 47337          M               O        101.0              STREET
# 68491          M               H        101.0              STREET
#
#                                Address                     Cross Street  \
# 19678                 200 W  AVENUE 26                              NaN
# 45031                            ADAMS                            GRAND
# 45311                         FLORENCE                            GRAND
# 47337                           VIGNES                          BAUCHET
# 68491  17TH                         ST  LOS ANGELES                  ST
#
#       Latitude  Longitude
# 19678  34.0786  -118.2174
# 45031  34.0265  -118.2723
# 45311  33.9747  -118.2803
# 47337  34.0589  -118.2323
# 68491  34.0323  -118.2621
#
# [5 rows x 22 columns]

# %% [markdown]
# ---
# ### Part III: Export Data

# %%
collision_data = 'traffic_collisions_' + str(today) + '.csv'
df.to_csv(collision_data, index=False)
print('CSV file has been exported')
# Out:
# CSV file has been exported
