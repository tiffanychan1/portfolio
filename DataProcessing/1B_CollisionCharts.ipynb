# %% [markdown]
# # Collision Charts
# ### Tiffany Chan
# <br>
# This notebook creates charts from the downloaded LA Open Data collision dataset to visualize the temporal distribution of these incidents.

# %% [markdown]
# ---
# ### Set Up & Read Dataset

# %%
import geopandas as gpd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import arcpy

# %%
gdb = r'C:\YourFolderPath\Data.gdb'
layer = 'Collision_Joined_Layer'
collision_data = gpd.read_file(gdb, layer=layer, driver='OpenFileGDB')
collision_data.head()

# %%
output_folder = r'C:\YourFolderPath\Collision Charts'

# %% [markdown]
# ---
# ### Area of the City

# %%
ax = sns.countplot(data=df, x=df['Area Name'], order=df['Area Name'].value_counts().index, color='green')

# adjust labels
plt.xlabel('Area', fontsize=16)
plt.ylabel('Number of Collisions', fontsize=16)
plt.title('Collisions per Area', fontsize=20)

# change tick label size
plt.xticks(fontsize=10)
plt.yticks(fontsize=12)

# change size of graph
fig = plt.gcf()
fig.set_size_inches(20, 10)

# remove chart border
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# add labels for each bar
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+10), fontsize=12)

plt.savefig(output_folder + '/CityArea.png')

# %% [markdown]
# ---
# ### Police Reporting District
# The 30 reporting districtions with the highest number of collisions

# %%
ax = sns.countplot(data=df, x=df['Reporting District'], order=df['Reporting District'].value_counts().iloc[:30].index, color='green')

# adjust labels
plt.xlabel('Police Reporting District', fontsize=16)
plt.ylabel('Number of Collisions', fontsize=16)
plt.title('Collisions per Reporting District', fontsize=20)

# change tick label size
plt.xticks(fontsize=13)
plt.yticks(fontsize=14)

# change size of graph
fig = plt.gcf()
fig.set_size_inches(20, 10)

# remove chart border
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# add labels for each bar
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.2, p.get_height()+1), fontsize=12)

plt.savefig(output_folder + '/PoliceReportingDistrict.png')

# %% [markdown]
# ---
# ### Hour of the Day

# %%
ax = sns.countplot(data=df, x=df['Hour'],  color='green')

# adjust labels
plt.xlabel('Hour of the Day (24-Hour Time)', fontsize=16)
plt.ylabel('Number of Collisions', fontsize=16)
plt.title('Collisions per Hour', fontsize=20)

# change tick label size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# change size of graph
fig = plt.gcf()
fig.set_size_inches(20, 10)

# remove chart border
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# add labels for each bar
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.2, p.get_height()+10), fontsize=12)

plt.savefig(output_folder + '/HourOfDay.png')

# %% [markdown]
# ---
# ### Day of the Week

# %%
#define order for days of the week
days_order = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

# %%
ax = sns.countplot(data=df, x=df['Day Of Week'], order=days_order, color='green')

# adjust labels
plt.xlabel('Day of the Week', fontsize=10)
plt.ylabel('Number of Collisions', fontsize=10)
plt.title('Collisions per Day of the Week', fontsize=12)

# change tick label size
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# change size of graph
fig = plt.gcf()
fig.set_size_inches(7, 5)

# remove chart border
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# add labels for each bar
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+25), fontsize=7)

plt.savefig(output_folder + '/DayOfWeek.png')

# %% [markdown]
# ---
# ### Month of the Year

# %%
#define order for months
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
              'August', 'September', 'October', 'November', 'December']

# %%
ax = sns.countplot(data=df, x=df['Month'], order=month_order, color='green')

# adjust labels
plt.xlabel('Month', fontsize=16)
plt.ylabel('Number of Collisions', fontsize=16)
plt.title('Collisions per Month', fontsize=20)

# change tick label size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# change size of graph
fig = plt.gcf()
fig.set_size_inches(20, 10)

# remove chart border
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# add labels for each bar
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+10), fontsize=12)

plt.savefig(output_folder + '/Month.png')
